# %%
# Out:
# 0 you
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4         print(idx,word)
#       5         print(corpus[word])
# ----> 6 num()
#
# Cell In[1], line 5, in num()
#       3 for idx,word in enumerate(corpus):
#       4     print(idx,word)
# ----> 5     print(corpus[word])
#
# TypeError: list indices must be integers or slices, not str
